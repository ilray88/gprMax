# %%
print('2')
# Out:
# 2

# %%
import sys
sys.path.append(r'D:\0ilraypan\git_jia\gprMax') #把gprMax安装路径添加至系统，使import可以找到gprMax模块
import os
from gprMax.gprMax import api
import numpy as np
from tools.plot_Bscan import get_output_data, mpl_plot
from tools.outputfiles_merge import merge_files
import matplotlib.pyplot as plt


num_scan = 3 #正演仿真次数（A扫描次数）->B扫描
geo_only = False #是否只生成模型图

path = os.getcwd()#获得当前脚本所在的文件路径
#print(path)
root = path  #指定输入文件的路径
files = os.listdir(root)   #得到路径下的文件夹名或者文件名，形成列表

# %%
for file in files:
    if file.endswith('.in'):  #找到.txt文件
        print(file)
        filename = root+'\\'+file  #得到文件名的绝对路径
        fi = filename[0:-3]        #去掉文件名后的.txt后缀,注意保留了前面的路径
        api(filename, n=num_scan, geometry_only=geo_only) #geometry_only：仅几何图形
        merge_files(fi, removefiles=False)
# Out:
# data_0.in
#
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.5 (Big Smoke)
#
#  Copyright (C) 2015-2020: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the
#   terms of the GNU General Public License as published by the Free Software
#   Foundation, either version 3 of the License, or (at your option) any later
#   version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY
#   WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR
#   A PARTICULAR PURPOSE.  See the GNU General Public License for more details.
#  You should have received a copy of the GNU General Public License along with
#   gprMax.  If not, see www.gnu.org/licenses.
#
# Host: JIAHOME | HUAWEI KLVC-WXX9 | 1 x Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz (4 cores, 8 cores with Hyper-Threading) | 15.8GiB RAM | Windows 10 (64-bit)
#
# --- Model 1/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_0.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 1, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_0.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_0.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.94526e-09 secs (1474 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=2, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=10, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.24m, 0.27m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 31.25cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 222.24it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 34.74it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 2     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 10    | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 6     | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 1.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.65% in material 'Mate2' whose wavelength sampled by 11 cells. Maximum significant frequency estimated as 4.17067e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_01.out
#
# Running simulation, model 1/3: 100%|██████| 1474/1474 [00:06<00:00, 237.45it/s]
# Memory (RAM) used: ~124MB
# Solving time [HH:MM:SS]: 0:00:06.220011
#
# --- Model 2/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_0.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 2, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_0.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_0.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.94526e-09 secs (1474 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=2, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=10, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.24m, 0.27m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 32.73cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 160.02it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 38.46it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 2     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 10    | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 6     | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 1.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.65% in material 'Mate2' whose wavelength sampled by 11 cells. Maximum significant frequency estimated as 4.17067e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_02.out
#
# Running simulation, model 2/3: 100%|██████| 1474/1474 [00:06<00:00, 240.40it/s]
# Memory (RAM) used: ~124MB
# Solving time [HH:MM:SS]: 0:00:06.143512
#
# --- Model 3/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_0.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 3, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_0.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_0.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.94526e-09 secs (1474 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=2, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=10, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.24m, 0.27m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 34.88cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 222.29it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 38.81it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 2     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 10    | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 6     | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 1.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.65% in material 'Mate2' whose wavelength sampled by 11 cells. Maximum significant frequency estimated as 4.17067e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_03.out
#
# Running simulation, model 3/3: 100%|██████| 1474/1474 [00:06<00:00, 236.79it/s]
# Memory (RAM) used: ~124MB
# Solving time [HH:MM:SS]: 0:00:06.236247
#
# === Simulation completed in [HH:MM:SS]: 0:00:22.704650 ========================
#
# data_1.in
#
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.5 (Big Smoke)
#
#  Copyright (C) 2015-2020: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the
#   terms of the GNU General Public License as published by the Free Software
#   Foundation, either version 3 of the License, or (at your option) any later
#   version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY
#   WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR
#   A PARTICULAR PURPOSE.  See the GNU General Public License for more details.
#  You should have received a copy of the GNU General Public License along with
#   gprMax.  If not, see www.gnu.org/licenses.
#
# Host: JIAHOME | HUAWEI KLVC-WXX9 | 1 x Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz (4 cores, 8 cores with Hyper-Threading) | 15.8GiB RAM | Windows 10 (64-bit)
#
# --- Model 1/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_1.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 1, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_1.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_1.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.4111e-09 secs (1361 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=2, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=8, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.54m, 0.34m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 25.18cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 166.68it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 30.68it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 2     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 8     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 5     | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 1.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.53% in material 'Mate2' whose wavelength sampled by 12 cells. Maximum significant frequency estimated as 4.20544e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_11.out
#
# Running simulation, model 1/3: 100%|██████| 1361/1361 [00:05<00:00, 229.86it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:05.933782
#
# --- Model 2/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_1.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 2, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_1.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_1.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.4111e-09 secs (1361 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=2, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=8, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.54m, 0.34m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 28.30cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 200.02it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 41.67it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 2     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 8     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 5     | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 1.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.53% in material 'Mate2' whose wavelength sampled by 12 cells. Maximum significant frequency estimated as 4.20544e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_12.out
#
# Running simulation, model 2/3: 100%|██████| 1361/1361 [00:06<00:00, 211.87it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:06.435854
#
# --- Model 3/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_1.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 3, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_1.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_1.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.4111e-09 secs (1361 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=2, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=8, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.54m, 0.34m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 32.77cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 199.75it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 35.09it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 2     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 8     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 5     | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 1.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.53% in material 'Mate2' whose wavelength sampled by 12 cells. Maximum significant frequency estimated as 4.20544e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_13.out
#
# Running simulation, model 3/3: 100%|██████| 1361/1361 [00:06<00:00, 219.78it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:06.203851
#
# === Simulation completed in [HH:MM:SS]: 0:00:23.000449 ========================
#
# data_2.in
#
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.5 (Big Smoke)
#
#  Copyright (C) 2015-2020: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the
#   terms of the GNU General Public License as published by the Free Software
#   Foundation, either version 3 of the License, or (at your option) any later
#   version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY
#   WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR
#   A PARTICULAR PURPOSE.  See the GNU General Public License for more details.
#  You should have received a copy of the GNU General Public License along with
#   gprMax.  If not, see www.gnu.org/licenses.
#
# Host: JIAHOME | HUAWEI KLVC-WXX9 | 1 x Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz (4 cores, 8 cores with Hyper-Threading) | 15.8GiB RAM | Windows 10 (64-bit)
#
# --- Model 1/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_2.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 1, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_2.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_2.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 4.26667e-09 secs (906 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=4, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=1, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.49m, 0.18m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 36.33cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 190.50it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 40.82it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 4     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 1     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 2.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 2.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.26% in material 'Mate1' whose wavelength sampled by 17 cells. Maximum significant frequency estimated as 4.21163e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_21.out
#
# Running simulation, model 1/3: 100%|████████| 906/906 [00:04<00:00, 200.63it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:04.528506
#
# --- Model 2/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_2.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 2, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_2.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_2.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 4.26667e-09 secs (906 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=4, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=1, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.49m, 0.18m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 36.15cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 200.00it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 37.04it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 4     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 1     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 2.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 2.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.26% in material 'Mate1' whose wavelength sampled by 17 cells. Maximum significant frequency estimated as 4.21163e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_22.out
#
# Running simulation, model 2/3: 100%|████████| 906/906 [00:04<00:00, 208.61it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:04.355882
#
# --- Model 3/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_2.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 3, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_2.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_2.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 4.26667e-09 secs (906 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=4, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=1, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.49m, 0.18m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 33.49cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 235.37it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 34.17it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 4     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 1     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 2.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 2.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.26% in material 'Mate1' whose wavelength sampled by 17 cells. Maximum significant frequency estimated as 4.21163e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_23.out
#
# Running simulation, model 3/3: 100%|████████| 906/906 [00:04<00:00, 202.64it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:04.483236
#
# === Simulation completed in [HH:MM:SS]: 0:00:17.281004 ========================
#
# data_3.in
#
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.5 (Big Smoke)
#
#  Copyright (C) 2015-2020: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the
#   terms of the GNU General Public License as published by the Free Software
#   Foundation, either version 3 of the License, or (at your option) any later
#   version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY
#   WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR
#   A PARTICULAR PURPOSE.  See the GNU General Public License for more details.
#  You should have received a copy of the GNU General Public License along with
#   gprMax.  If not, see www.gnu.org/licenses.
#
# Host: JIAHOME | HUAWEI KLVC-WXX9 | 1 x Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz (4 cores, 8 cores with Hyper-Threading) | 15.8GiB RAM | Windows 10 (64-bit)
#
# --- Model 1/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_3.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 1, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_3.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_3.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 8.00444e-09 secs (1698 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=8, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=7, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.47m, 0.2m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 33.33cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 190.53it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 36.67it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 8     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 7     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 7.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 4.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.54% in material 'Mate1' whose wavelength sampled by 12 cells. Maximum significant frequency estimated as 4.2447e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_31.out
#
# Running simulation, model 1/3: 100%|██████| 1698/1698 [00:07<00:00, 230.55it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:07.376220
#
# --- Model 2/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_3.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 2, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_3.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_3.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 8.00444e-09 secs (1698 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=8, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=7, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.47m, 0.2m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 34.09cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 166.69it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 40.00it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 8     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 7     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 7.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 4.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.54% in material 'Mate1' whose wavelength sampled by 12 cells. Maximum significant frequency estimated as 4.2447e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_32.out
#
# Running simulation, model 2/3: 100%|██████| 1698/1698 [00:07<00:00, 223.44it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:07.612548
#
# --- Model 3/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_3.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 3, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_3.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_3.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 8.00444e-09 secs (1698 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=8, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=7, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.47m, 0.2m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 32.75cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 159.91it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 39.56it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 8     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 7     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 7.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 4.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.54% in material 'Mate1' whose wavelength sampled by 12 cells. Maximum significant frequency estimated as 4.2447e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_33.out
#
# Running simulation, model 3/3: 100%|██████| 1698/1698 [00:07<00:00, 228.68it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:07.438581
#
# === Simulation completed in [HH:MM:SS]: 0:00:26.557769 ========================
#
# data_4.in
#
# === Electromagnetic modelling software based on the Finite-Difference Time-Domain (FDTD) method
#
#     www.gprmax.com   __  __
#      __ _ _ __  _ __|  \/  | __ ___  __
#     / _` | '_ \| '__| |\/| |/ _` \ \/ /
#    | (_| | |_) | |  | |  | | (_| |>  <
#     \__, | .__/|_|  |_|  |_|\__,_/_/\_\
#     |___/|_|
#                      v3.1.5 (Big Smoke)
#
#  Copyright (C) 2015-2020: The University of Edinburgh
#  Authors: Craig Warren and Antonis Giannopoulos
#
#  gprMax is free software: you can redistribute it and/or modify it under the
#   terms of the GNU General Public License as published by the Free Software
#   Foundation, either version 3 of the License, or (at your option) any later
#   version.
#  gprMax is distributed in the hope that it will be useful, but WITHOUT ANY
#   WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR
#   A PARTICULAR PURPOSE.  See the GNU General Public License for more details.
#  You should have received a copy of the GNU General Public License along with
#   gprMax.  If not, see www.gnu.org/licenses.
#
# Host: JIAHOME | HUAWEI KLVC-WXX9 | 1 x Intel(R) Core(TM) i5-10210U CPU @ 1.60GHz (4 cores, 8 cores with Hyper-Threading) | 15.8GiB RAM | Windows 10 (64-bit)
#
# --- Model 1/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_4.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 1, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_4.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_4.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.03727e-09 secs (1281 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=3, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.21m, 0.2m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 33.26cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 181.89it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 41.67it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 6     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 3     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 4.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.41% in material 'Mate1' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.30259e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_41.out
#
# Running simulation, model 1/3: 100%|██████| 1281/1281 [00:05<00:00, 219.20it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:05.856892
#
# --- Model 2/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_4.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 2, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_4.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_4.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.03727e-09 secs (1281 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=3, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.21m, 0.2m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 34.09cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 198.52it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 35.09it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 6     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 3     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 4.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.41% in material 'Mate1' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.30259e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_42.out
#
# Running simulation, model 2/3: 100%|██████| 1281/1281 [00:05<00:00, 220.93it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:05.809775
#
# --- Model 3/3, input file: D:\0ilraypan\git_jia\gprMax\in_data\data_4.in ------
#
# Constants/variables used/available for Python scripting: {c: 299792458.0, current_model_run: 3, e0: 8.854187817620389e-12, inputfile: D:\0ilraypan\git_jia\gprMax\in_data\data_4.in, m0: 1.2566370614359173e-06, number_model_runs: 3, z0: 376.73031346177066}
#
# Model title: data_4.in
# Number of CPU (OpenMP) threads: 4
# Spatial discretisation: 0.002 x 0.002 x 0.002m
# Domain size: 1 x 0.5 x 0.002m (500 x 250 x 1 = 125000 cells)
# Mode: 2D TMz
# Time step (at CFL limit): 4.71731e-12 secs
# Time window: 6.03727e-09 secs (1281 iterations)
# Simple sources will step 0.01m, 0m, 0m for each model run.
# All receivers will step 0.01m, 0m, 0m for each model run.
#
# Waveform my_ricker of type ricker with maximum amplitude scaling 1, frequency 1.5e+09Hz created.
# WARNING: '#hertzian_dipole: z 0.05 0.49 0 my_ricker' sources and receivers should not normally be positioned within the PML.
# Hertzian dipole with polarity z at 0.05m, 0.49m, 0m, using waveform my_ricker created.
# WARNING: '#rx: 0.055 0.49 0' sources and receivers should not normally be positioned within the PML.
# Receiver at 0.054m, 0.49m, 0m with output component(s) Ex, Ey, Ez, Hx, Hy, Hz created.
# Material Mate1 with eps_r=6, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
# Material Mate2 with eps_r=3, sigma=0 S/m; mu_r=1, sigma*=0 Ohm/m created.
#
# Memory (RAM) required: ~64.9MB
#
# Box from 0m, 0.24m, 0m, to 1m, 0.44m, 0.002m of material(s) Mate1 created, dielectric smoothing is on.
# Box from 0m, 0m, 0m, to 1m, 0.24m, 0.002m of material(s) Mate2 created, dielectric smoothing is on.
# Cylindrical sector with centre 0.21m, 0.2m, radius 0.02m, starting angle 180.0 degrees, sector angle 180.0 degrees, thickness 0.002m, of material(s) pec created, dielectric smoothing is off.
# Processing geometry related cmds: 100%|████████| 3/3 [00:00<00:00, 28.85cmds/s]
#
# PML: formulation: HORIPML, order: 1, thickness: x0: 10, y0: 10, z0: 0, xmax: 10, ymax: 10, zmax: 0 cells
# Building PML boundaries: 100%|██████████████████| 4/4 [00:00<00:00, 162.91it/s]
#
# Building main grid: 100%|████████████████████████| 2/2 [00:00<00:00, 28.75it/s]
#
# Materials:
#     |                                   |                     |       | sigma |      | sigma*  | Dielectric
#  ID | Name                              | Type                | eps_r | [S/m] | mu_r | [Ohm/m] | smoothable
# ----+-----------------------------------+---------------------+-------+-------+------+---------+------------
#   0 | pec                               | builtin             | 1     | inf   | 1    | 0       | False
#   1 | free_space                        | builtin             | 1     | 0     | 1    | 0       | True
#   2 | Mate1                             |                     | 6     | 0     | 1    | 0       | True
#   3 | Mate2                             |                     | 3     | 0     | 1    | 0       | True
#   4 | Mate1+Mate1+Mate2+Mate2           | dielectric-smoothed | 4.5   | 0     | 1    | 0       | True
#   5 | free_space+free_space+Mate1+Mate1 | dielectric-smoothed | 3.5   | 0     | 1    | 0       | True
#
# Numerical dispersion analysis: estimated largest physical phase-velocity error is -0.41% in material 'Mate1' whose wavelength sampled by 14 cells. Maximum significant frequency estimated as 4.30259e+09Hz
#
# Output file: D:\0ilraypan\git_jia\gprMax\in_data\data_43.out
#
# Running simulation, model 3/3: 100%|██████| 1281/1281 [00:06<00:00, 194.67it/s]
# Memory (RAM) used: ~125MB
# Solving time [HH:MM:SS]: 0:00:06.595959
#
# === Simulation completed in [HH:MM:SS]: 0:00:22.263541 ========================

# %%
        """B扫描绘图"""
        filename_b = fi+'_merged.out'
        rxnumber = 1
        rxcomponent = 'Ez'
        #获取回波数据
        outputdata, dt = get_output_data(filename_b, rxnumber, rxcomponent)
        #保存回波数据
        fi2 = fi.split('/')[-1]  #得到文件名，去掉了前面的路径
        fi2
        out_path = path+'/out_data'
        if (os.path.exists(out_path)):
            pass
        else:
            os.mkdir(out_path)
        np.savetxt(out_path+'/'+fi2+'.txt',outputdata,delimiter=' ')#未去除直达波

        #绘图
        plt.imshow(outputdata, extent=[0, outputdata.shape[1], outputdata.shape[0], 0], interpolation='nearest', aspect='auto', cmap='gray',
                   vmin=-np.amax(np.abs(outputdata)), vmax=np.amax(np.abs(outputdata)))
        img_path = path+'/img_data'
        if (os.path.exists(img_path)):
            pass
        else:
            os.mkdir(img_path)
        plt.savefig(img_path+'/'+fi2+'.png',dpi=300)#保存图片
        # plt.show()
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-2b5fbfa2969e> in <module>()
#      13 else:
#      14     os.mkdir(out_path)
# ---> 15 np.savetxt(out_path+'/'+fi2+'.txt',outputdata,delimiter=' ')#未去除直达波
#      16
#      17 #绘图
#
# d:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments)
#    1151         else:
#    1152             if sys.version_info[0] >= 3:
# -> 1153                 fh = open(fname, 'wb')
#    1154             else:
#    1155                 fh = open(fname, 'w')
#
# OSError: [Errno 22] Invalid argument: 'D:\\0ilraypan\\git_jia\\gprMax\\in_data/out_data/D:\\0ilraypan\\git_jia\\gprMax\\in_data\\data_4.txt'
